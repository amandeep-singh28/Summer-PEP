# %%
from langchain_openai import OpenAIEmbeddings
from langchain_chroma import Chroma
from langchain_core.documents import Document
import os
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %%
doc1 = Document(
    page_content="Albert Einstein was a theoretical physicist known for developing the theory of relativity, one of the two pillars of modern physics.",
    metadata={"field": "Physics", "country": "Germany"}
)

doc2 = Document(
    page_content="Mahatma Gandhi was a leader of India’s non-violent independence movement against British rule and is celebrated for his philosophy of peaceful resistance.",
    metadata={"field": "Politics", "country": "India"}
)

doc3 = Document(
    page_content="Marie Curie was a pioneering scientist who conducted groundbreaking research on radioactivity and was the first woman to win a Nobel Prize.",
    metadata={"field": "Chemistry", "country": "Poland"}
)

doc4 = Document(
    page_content="Leonardo da Vinci was a Renaissance artist and inventor, best known for masterpieces like the Mona Lisa and The Last Supper.",
    metadata={"field": "Art", "country": "Italy"}
)

doc5 = Document(
    page_content="Martin Luther King Jr. was an American civil rights leader who advocated for equality through non-violent civil disobedience.",
    metadata={"field": "Civil Rights", "country": "USA"}
)
docs=[doc1,doc2,doc3,doc4,doc5]
docs
# Out:
# [Document(metadata={'field': 'Physics', 'country': 'Germany'}, page_content='Albert Einstein was a theoretical physicist known for developing the theory of relativity, one of the two pillars of modern physics.'),
#  Document(metadata={'field': 'Politics', 'country': 'India'}, page_content='Mahatma Gandhi was a leader of India’s non-violent independence movement against British rule and is celebrated for his philosophy of peaceful resistance.'),
#  Document(metadata={'field': 'Chemistry', 'country': 'Poland'}, page_content='Marie Curie was a pioneering scientist who conducted groundbreaking research on radioactivity and was the first woman to win a Nobel Prize.'),
#  Document(metadata={'field': 'Art', 'country': 'Italy'}, page_content='Leonardo da Vinci was a Renaissance artist and inventor, best known for masterpieces like the Mona Lisa and The Last Supper.'),
#  Document(metadata={'field': 'Civil Rights', 'country': 'USA'}, page_content='Martin Luther King Jr. was an American civil rights leader who advocated for equality through non-violent civil disobedience.')]

# %%
vector_store=Chroma(
  embedding_function=OpenAIEmbeddings(api_key = os.getenv("OPENAI_API_KEY")), # which embedding model is used 
  persist_directory='my_file_db', #directory in which all embedding vectors will be stores
  collection_name='celebrities', #collection inside the directory
)

# %%
#add documents
vector_store.add_documents(docs)
# Out:
# ['906e6d1b-50c6-4cd7-b088-b34c5d847a20',
#  '735a1eeb-3001-452c-8cba-31d430ebcd44',
#  'a2bd10c6-f7c4-4268-b9a5-04d07975254e',
#  'a4be55ef-cf01-48eb-9d7c-1e03b531eb00',
#  'bf143b11-150f-49d4-a48e-882736ad4386']

# %%
#view documents (includes will print all the included element from docs)
vector_store.get(include=['embeddings','documents','metadatas'])
# Out:
# {'ids': ['906e6d1b-50c6-4cd7-b088-b34c5d847a20',
#   '735a1eeb-3001-452c-8cba-31d430ebcd44',
#   'a2bd10c6-f7c4-4268-b9a5-04d07975254e',
#   'a4be55ef-cf01-48eb-9d7c-1e03b531eb00',
#   'bf143b11-150f-49d4-a48e-882736ad4386'],
#  'embeddings': array([[ 2.78717768e-03,  4.51404974e-03,  1.56178058e-03, ...,
#          -9.25248460e-05, -8.17861501e-03, -1.71633102e-02],
#         [-3.27674747e-02,  3.37490463e-03, -1.09790433e-02, ...,
#          -1.83589961e-02,  3.06286220e-03, -1.36086820e-02],
#         [-2.63270028e-02,  5.92933020e-06,  2.28619413e-03, ...,
#          -7.46512366e-03, -1.97701361e-02, -5.98454103e-03],
#         [ 2.64541688e-03,  9.41636879e-03, -7.79607042e-04, ...,
#           5.49170691e-05,  6.56577153e-03, -2.54611596e-02],
#         [-2.35927384e-02, -8.56228080e-03, -2.80783325e-02, ...,
#          -1.42869893e-02, -6.74078241e-03, -3.18452413e-03]],
#        shape=(5, 1536)),
#  'documents': ['Albert Einstein was a theoretical physicist known for developing the theory of relativity, one of the two pillars of modern physics.',
#   'Mahatma Gandhi was a leader of India’s non-violent independence movement against British rule and is celebrated for his philosophy of peaceful resistance.',
#   'Marie Curie was a pioneering scientist who conducted groundbreaking research on radioactivity and was the first woman to win a Nobel Prize.',
#   'Leonardo da Vinci was a Renaissance artist and inventor, best known for masterpieces like the Mona Lisa and The Last Supper.',
#   'Martin Luther King Jr. was an American civil rights leader who advocated for equality through non-violent civil disobedience.'],
#  'uris': None,
#  'included': ['embeddings', 'documents', 'metadatas'],
#  'data': None,
#  'metadatas': [{'field': 'Physics', 'country': 'Germany'},
#   {'field': 'Politics', 'country': 'India'},
#   {'field': 'Chemistry', 'country': 'Poland'},
#   {'country': 'Italy', 'field': 'Art'},
#   {'country': 'USA', 'field': 'Civil Rights'}]}

# %%
vector_store.similarity_search_with_score(
  query='Who among these are a physicist',
  k = 6 # number of outcome you want (means if there are 3 physicist then 2 with high similarity score will be returned as k is 2
)
# Out:
# [(Document(id='906e6d1b-50c6-4cd7-b088-b34c5d847a20', metadata={'country': 'Germany', 'field': 'Physics'}, page_content='Albert Einstein was a theoretical physicist known for developing the theory of relativity, one of the two pillars of modern physics.'),
#   0.35800111293792725),
#  (Document(id='a2bd10c6-f7c4-4268-b9a5-04d07975254e', metadata={'field': 'Chemistry', 'country': 'Poland'}, page_content='Marie Curie was a pioneering scientist who conducted groundbreaking research on radioactivity and was the first woman to win a Nobel Prize.'),
#   0.4623076915740967),
#  (Document(id='a4be55ef-cf01-48eb-9d7c-1e03b531eb00', metadata={'field': 'Art', 'country': 'Italy'}, page_content='Leonardo da Vinci was a Renaissance artist and inventor, best known for masterpieces like the Mona Lisa and The Last Supper.'),
#   0.531502366065979),
#  (Document(id='735a1eeb-3001-452c-8cba-31d430ebcd44', metadata={'field': 'Politics', 'country': 'India'}, page_content='Mahatma Gandhi was a leader of India’s non-violent independence movement against British rule and is celebrated for his philosophy of peaceful resistance.'),
#   0.586816132068634)]

# %%
# search with similarity score. This will print the same as above but with similarity score
vector_store.similarity_search_with_score(
    query='Who among these are a physicist',
    k=2
)
# Out:
# [(Document(id='906e6d1b-50c6-4cd7-b088-b34c5d847a20', metadata={'country': 'Germany', 'field': 'Physics'}, page_content='Albert Einstein was a theoretical physicist known for developing the theory of relativity, one of the two pillars of modern physics.'),
#   0.35800111293792725),
#  (Document(id='a2bd10c6-f7c4-4268-b9a5-04d07975254e', metadata={'field': 'Chemistry', 'country': 'Poland'}, page_content='Marie Curie was a pioneering scientist who conducted groundbreaking research on radioactivity and was the first woman to win a Nobel Prize.'),
#   0.4623076915740967)]

# %%
#meta data filtering
vector_store.similarity_search_with_score(
  query="",
  filter={'country': 'India'}
)
# Out:
# [(Document(id='735a1eeb-3001-452c-8cba-31d430ebcd44', metadata={'country': 'India', 'field': 'Politics'}, page_content='Mahatma Gandhi was a leader of India’s non-violent independence movement against British rule and is celebrated for his philosophy of peaceful resistance.'),
#   0.618714451789856)]

# %%
#updating document
updated_doc1 = Document(
    page_content="Albert Einstein revolutionized modern physics with his contributions to quantum mechanics and the theory of general relativity. Beyond science, he was a passionate advocate for civil rights and a vocal critic of authoritarianism.",
    metadata={"field": "Physics", "country": "Germany", "notable_for": "Relativity & Humanitarianism"}
)

# %%
vector_store.get(include=['documents'])
# Out:
# {'ids': ['906e6d1b-50c6-4cd7-b088-b34c5d847a20',
#   '735a1eeb-3001-452c-8cba-31d430ebcd44',
#   'a2bd10c6-f7c4-4268-b9a5-04d07975254e',
#   'a4be55ef-cf01-48eb-9d7c-1e03b531eb00',
#   'bf143b11-150f-49d4-a48e-882736ad4386'],
#  'embeddings': None,
#  'documents': ['Albert Einstein was a theoretical physicist known for developing the theory of relativity, one of the two pillars of modern physics.',
#   'Mahatma Gandhi was a leader of India’s non-violent independence movement against British rule and is celebrated for his philosophy of peaceful resistance.',
#   'Marie Curie was a pioneering scientist who conducted groundbreaking research on radioactivity and was the first woman to win a Nobel Prize.',
#   'Leonardo da Vinci was a Renaissance artist and inventor, best known for masterpieces like the Mona Lisa and The Last Supper.',
#   'Martin Luther King Jr. was an American civil rights leader who advocated for equality through non-violent civil disobedience.'],
#  'uris': None,
#  'included': ['documents'],
#  'data': None,
#  'metadatas': None}

# %%
vector_store.delete(ids=['bf143b11-150f-49d4-a48e-882736ad4386'])

# %%
vector_store.get(include=['documents'])
# Out:
# {'ids': ['906e6d1b-50c6-4cd7-b088-b34c5d847a20',
#   '735a1eeb-3001-452c-8cba-31d430ebcd44',
#   'a2bd10c6-f7c4-4268-b9a5-04d07975254e',
#   'a4be55ef-cf01-48eb-9d7c-1e03b531eb00'],
#  'embeddings': None,
#  'documents': ['Albert Einstein was a theoretical physicist known for developing the theory of relativity, one of the two pillars of modern physics.',
#   'Mahatma Gandhi was a leader of India’s non-violent independence movement against British rule and is celebrated for his philosophy of peaceful resistance.',
#   'Marie Curie was a pioneering scientist who conducted groundbreaking research on radioactivity and was the first woman to win a Nobel Prize.',
#   'Leonardo da Vinci was a Renaissance artist and inventor, best known for masterpieces like the Mona Lisa and The Last Supper.'],
#  'uris': None,
#  'included': ['documents'],
#  'data': None,
#  'metadatas': None}
