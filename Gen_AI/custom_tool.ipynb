# %%
from langchain_openai import ChatOpenAI

# %%
from langchain_core.tools import tool

@tool
def add(num1: int, num2: int):
    """Adds two numbers."""
    return num1 + num2

# %%
result = add.invoke({"num1": 15, "num2": 25})

print(result)
# Out:
# 40
