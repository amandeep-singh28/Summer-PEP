# %%
from crewai import Agent, Task, Crew, LLM
from crewai.tools import BaseTool
from crewai_tools import TavilySearchTool
from dotenv import load_dotenv
import os
load_dotenv()
# Out:
# True

# %%
llm = LLM(
    model="llama-3.3-70b-versatile",
    api_key=os.getenv("GROK_API_KEY"),
    base_url="https://api.groq.com/openai/v1"
)

# %%
search_tool = TavilySearchTool()

# %%
agent = Agent(
    role="Professional Blog Writer",

    goal="Research the given topic using Tavily Search and write an informative blog.",

    backstory="""
    You are an expert technical blog writer.
    Before writing any blog, always search the internet using the Tavily Search Tool
    to collect the latest and most accurate information.
    """,

    llm=llm,

    tools=[search_tool],

    verbose=True
)

# %%
topic = """
Virat Kohli
"""

# %%
task = Task(
    description="""
    Write a detailed blog on the topic:
    {topic}

    First use the Tavily Search Tool to gather relevant information.
    Then write a well-structured blog using the retrieved information.
    """,

    expected_output="""
    A professional blog with:
    - Title
    - Introduction
    - Main Content
    - Conclusion
    """,

    agent=agent
)

# %%
crew = Crew(
    agents=[agent],
    tasks=[task],
    verbose=True
)

# %%
result = await crew.kickoff_async(
    inputs={
        "topic": topic
    }
)
# Out:
# ╭─────────────────────────────────────────── 🚀 Crew Execution Started ───────────────────────────────────────────╮
# │                                                                                                                 │
# │  Crew Execution Started                                                                                         │
# │  Name: crew                                                                                                     │
# │  ID: e4a15ace-f147-4aa4-8ad5-0db143ddf518                                                                       │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# ...

# %%
from IPython.display import Markdown, display

display(Markdown(result.raw))
# Out:
# # Virat Kohli: The King of Cricket
#
# ## Introduction
#
# Virat Kohli is one of the most renowned cricketers of our time, known for his exceptional batting skills and impressive leadership qualities. Born on November 5, 1988, in Delhi, India, Kohli has risen to become one of the greatest cricketers in the world. With a career spanning over a decade, Kohli has achieved numerous milestones and has been instrumental in India's success in various international tournaments.
#
# ## Early Life and Career
#
# Kohli's journey in cricket began at a young age, and he quickly made a name for himself in the junior cricket circuit. He made his debut in List A cricket in 2006 and soon found himself playing for the Indian Under-19 team. Kohli's impressive performance in the 2008 Under-19 World Cup, where he led the team to victory, caught the attention of the cricketing world.
#
# ## Rise to Fame
#
# ...
