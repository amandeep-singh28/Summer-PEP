# %%
from crewai import Agent, Task, Crew, LLM
from dotenv import load_dotenv
import os

load_dotenv()
# Out:
# True

# %%
llm = LLM(
    model="llama-3.3-70b-versatile",
    api_key=os.getenv("GROK_API_KEY"),
    base_url="https://api.groq.com/openai/v1"
)

# %%
email = """
hey team,
wip is almost done.
I will send the report tomorrow
thanks
"""

# %%
email_agent = Agent(
    role = "Professional Email Writer",
    goal = "Rewrite emails in a professional tone",
    backstory = (
        "You are an expert business communication specialist who writes clear, polite, and professional emails"
    ),
    llm = llm,
    verbose = True
)

# %%
task = Task(
    description = """
    Rewrite the following email professionally.
    Expand abbreviations if possible

    Email:
    {email}
    """,
    expected_output = "A polished professional email",
    agent = email_agent
)

# %%
crew = Crew(
    agents = [email_agent],
    tasks = [task],
    verbose = True
)

# %%
result = await crew.kickoff_async(
    inputs = {
        "email" : email
    }
)
# Out:
# ╭─────────────────────────────────────────── 🚀 Crew Execution Started ───────────────────────────────────────────╮
# │                                                                                                                 │
# │  Crew Execution Started                                                                                         │
# │  Name: crew                                                                                                     │
# │  ID: 255623b8-716b-4b2c-926b-11472542225e                                                                       │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭──────────────────────────────────────────────── 📋 Task Started ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Task Started                                                                                                   │
# │  Name:                                                                                                          │
# │      Rewrite the following email professionally.                                                                │
# │      Expand abbreviations if possible                                                                           │
# │                                                                                                                 │
# │      Email:                                                                                                     │
# │                                                                                                                 │
# │  hey team,                                                                                                      │
# │  wip is almost done.                                                                                            │
# │  I will send the report tomorrow                                                                                │
# │  thanks                                                                                                         │
# │                                                                                                                 │
# │                                                                                                                 │
# │  ID: fc83a4cb-9c19-4466-84eb-4d2ea7b2c64a                                                                       │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭─────────────────────────────────────────────── 🤖 Agent Started ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Agent: Professional Email Writer                                                                               │
# │                                                                                                                 │
# │  Task:                                                                                                          │
# │      Rewrite the following email professionally.                                                                │
# │      Expand abbreviations if possible                                                                           │
# │                                                                                                                 │
# │      Email:                                                                                                     │
# │                                                                                                                 │
# │  hey team,                                                                                                      │
# │  wip is almost done.                                                                                            │
# │  I will send the report tomorrow                                                                                │
# │  thanks                                                                                                         │
# │                                                                                                                 │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# [Finalize] todos_count=0, todos_with_results=0
# ╭───────────────────────────────────────────── ✅ Agent Final Answer ─────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Agent: Professional Email Writer                                                                               │
# │                                                                                                                 │
# │  Final Answer:                                                                                                  │
# │  Subject: Update on Work in Progress and Forthcoming Report                                                     │
# │                                                                                                                 │
# │  Dear Team,                                                                                                     │
# │                                                                                                                 │
# │  I am pleased to inform you that the work in progress (WIP) is nearing completion. I anticipate that all tasks  │
# │  will be finalized shortly, and I will be able to share the final outcome with you.                             │
# │                                                                                                                 │
# │  Regarding the report, I will submit it to you tomorrow. The document will provide a comprehensive overview of  │
# │  the project's progress, highlighting key accomplishments and findings.                                         │
# │                                                                                                                 │
# │  I would like to take this opportunity to express my gratitude for your continued support and cooperation       │
# │  throughout this project. Your contributions have been invaluable, and I appreciate the effort each of you has  │
# │  invested.                                                                                                      │
# │                                                                                                                 │
# │  Thank you for your understanding, and I look forward to sharing the report with you tomorrow.                  │
# │                                                                                                                 │
# │  Best regards,                                                                                                  │
# │  [Your Name]                                                                                                    │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭────────────────────────────────────────────── 📋 Task Completion ───────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Task Completed                                                                                                 │
# │  Name:                                                                                                          │
# │      Rewrite the following email professionally.                                                                │
# │      Expand abbreviations if possible                                                                           │
# │                                                                                                                 │
# │      Email:                                                                                                     │
# │                                                                                                                 │
# │  hey team,                                                                                                      │
# │  wip is almost done.                                                                                            │
# │  I will send the report tomorrow                                                                                │
# │  thanks                                                                                                         │
# │                                                                                                                 │
# │                                                                                                                 │
# │  Agent: Professional Email Writer                                                                               │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭──────────────────────────────────────────────── Crew Completion ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Crew Execution Completed                                                                                       │
# │  Name: crew                                                                                                     │
# │  ID: 255623b8-716b-4b2c-926b-11472542225e                                                                       │
# │  Final Output: Subject: Update on Work in Progress and Forthcoming Report                                       │
# │                                                                                                                 │
# │  Dear Team,                                                                                                     │
# │                                                                                                                 │
# │  I am pleased to inform you that the work in progress (WIP) is nearing completion. I anticipate that all tasks  │
# │  will be finalized shortly, and I will be able to share the final outcome with you.                             │
# │                                                                                                                 │
# │  Regarding the report, I will submit it to you tomorrow. The document will provide a comprehensive overview of  │
# │  the project's progress, highlighting key accomplishments and findings.                                         │
# │                                                                                                                 │
# │  I would like to take this opportunity to express my gratitude for your continued support and cooperation       │
# │  throughout this project. Your contributions have been invaluable, and I appreciate the effort each of you has  │
# │  invested.                                                                                                      │
# │                                                                                                                 │
# │  Thank you for your understanding, and I look forward to sharing the report with you tomorrow.                  │
# │                                                                                                                 │
# │  Best regards,                                                                                                  │
# │  [Your Name]                                                                                                    │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
#
# </pre>
# ╭─────────────────────────────────────────── Tracing Preference Saved ────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Info: Tracing has been disabled.                                                                               │
# │                                                                                                                 │
# │  Your preference has been saved. Future Crew/Flow executions will not collect traces.                           │
# │                                                                                                                 │
# │  To enable tracing later, do any one of these:                                                                  │
# │  • Set tracing=True in your Crew/Flow code                                                                      │
# │  • Set CREWAI_TRACING_ENABLED=true in your project's .env file                                                  │
# │  • Run: crewai traces enable                                                                                    │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>

# %%
print(result)
# Out:
# Subject: Update on Work in Progress and Forthcoming Report
#
# Dear Team,
#
# I am pleased to inform you that the work in progress (WIP) is nearing completion. I anticipate that all tasks will be finalized shortly, and I will be able to share the final outcome with you.
#
# Regarding the report, I will submit it to you tomorrow. The document will provide a comprehensive overview of the project's progress, highlighting key accomplishments and findings.
#
# I would like to take this opportunity to express my gratitude for your continued support and cooperation throughout this project. Your contributions have been invaluable, and I appreciate the effort each of you has invested.
#
# Thank you for your understanding, and I look forward to sharing the report with you tomorrow.
#
# Best regards,
# [Your Name]
